# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['median_house_value'],axis=1)
y=df['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_df=x_train.join(y_train)

# %%
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6424     -118.00     34.14                  39         1302           303.0
# 12977    -121.32     38.67                  31         2532           479.0
# 10064    -121.03     39.37                  15         1337           326.0
# 16162    -122.50     37.78                  50         1922           427.0
# 4784     -118.32     34.03                  47         1082           198.0
# ...          ...       ...                 ...          ...             ...
# 6597     -118.16     34.18                  44         1870           389.0
# 9632     -121.01     37.25                  16         2216           458.0
# 14437    -117.24     32.80                  18         2205           661.0
# 871      -122.07     37.52                   3        14014          2861.0
# 15350    -117.30     33.26                  23         1678           275.0
#
#        population  households  median_income ocean_proximity  \
# 6424          800         291         3.2723          INLAND
# 12977        1396         467         4.0417          INLAND
# 10064        1172         306         2.6341          INLAND
# 16162        1049         443         3.5833        NEAR BAY
# 4784          455         193         3.0132       <1H OCEAN
# ...           ...         ...            ...             ...
# 6597         1345         391         1.8932       <1H OCEAN
# 9632         1135         424         2.7316          INLAND
# 14437         874         580         3.8018      NEAR OCEAN
# 871          7205        2753         6.0824        NEAR BAY
# 15350        1227         264         4.1713       <1H OCEAN
#
#        median_house_value
# 6424               166900
# 12977              114500
# 10064               85000
# 16162              348500
# 4784               223200
# ...                   ...
# 6597               136100
# 9632                97500
# 14437              112500
# 871                273500
# 15350              133800
#
# [16346 rows x 10 columns]

# %%
train_df.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.loc[:,train_df.columns!='ocean_proximity'].corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_df['total_rooms']=np.log(train_df['total_rooms']+1)
train_df['total_bedrooms']=np.log(train_df['total_bedrooms']+1)
train_df['population']=np.log(train_df['population']+1)
train_df['households']=np.log(train_df['households']+1)

# %%
train_df.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7263
# INLAND        5182
# NEAR OCEAN    2086
# NEAR BAY      1813
# ISLAND           2
# Name: count, dtype: int64

# %%
train_df.join(pd.get_dummies(train_df.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6424     -118.00     34.14                  39     7.172425        5.717028
# 12977    -121.32     38.67                  31     7.837160        6.173786
# 10064    -121.03     39.37                  15     7.198931        5.789960
# 16162    -122.50     37.78                  50     7.561642        6.059123
# 4784     -118.32     34.03                  47     6.987490        5.293305
# ...          ...       ...                 ...          ...             ...
# 6597     -118.16     34.18                  44     7.534228        5.966147
# 9632     -121.01     37.25                  16     7.703910        6.129050
# 14437    -117.24     32.80                  18     7.698936        6.495266
# 871      -122.07     37.52                   3     9.547883        7.959276
# 15350    -117.30     33.26                  23     7.425954        5.620401
#
#        population  households  median_income ocean_proximity  \
# 6424     6.685861    5.676754         3.2723          INLAND
# 12977    7.242082    6.148468         4.0417          INLAND
# 10064    7.067320    5.726848         2.6341          INLAND
# 16162    6.956545    6.095825         3.5833        NEAR BAY
# 4784     6.122493    5.267858         3.0132       <1H OCEAN
# ...           ...         ...            ...             ...
# 6597     7.204893    5.971262         1.8932       <1H OCEAN
# 9632     7.035269    6.052089         2.7316          INLAND
# 14437    6.774224    6.364751         3.8018      NEAR OCEAN
# 871      8.882669    7.920810         6.0824        NEAR BAY
# 15350    7.113142    5.579730         4.1713       <1H OCEAN
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6424               166900      False    True   False     False       False
# 12977              114500      False    True   False     False       False
# 10064               85000      False    True   False     False       False
# 16162              348500      False   False   False      True       False
# 4784               223200       True   False   False     False       False
# ...                   ...        ...     ...     ...       ...         ...
# 6597               136100       True   False   False     False       False
# 9632                97500      False    True   False     False       False
# 14437              112500      False   False   False     False        True
# 871                273500      False   False   False      True       False
# 15350              133800       True   False   False     False       False
#
# [16346 rows x 15 columns]

# %%
train_df=train_df.join(pd.get_dummies(train_df.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6424     -118.00     34.14                  39     7.172425        5.717028
# 12977    -121.32     38.67                  31     7.837160        6.173786
# 10064    -121.03     39.37                  15     7.198931        5.789960
# 16162    -122.50     37.78                  50     7.561642        6.059123
# 4784     -118.32     34.03                  47     6.987490        5.293305
# ...          ...       ...                 ...          ...             ...
# 6597     -118.16     34.18                  44     7.534228        5.966147
# 9632     -121.01     37.25                  16     7.703910        6.129050
# 14437    -117.24     32.80                  18     7.698936        6.495266
# 871      -122.07     37.52                   3     9.547883        7.959276
# 15350    -117.30     33.26                  23     7.425954        5.620401
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6424     6.685861    5.676754         3.2723              166900      False
# 12977    7.242082    6.148468         4.0417              114500      False
# 10064    7.067320    5.726848         2.6341               85000      False
# 16162    6.956545    6.095825         3.5833              348500      False
# 4784     6.122493    5.267858         3.0132              223200       True
# ...           ...         ...            ...                 ...        ...
# 6597     7.204893    5.971262         1.8932              136100       True
# 9632     7.035269    6.052089         2.7316               97500      False
# 14437    6.774224    6.364751         3.8018              112500      False
# 871      8.882669    7.920810         6.0824              273500      False
# 15350    7.113142    5.579730         4.1713              133800       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6424     True   False     False       False
# 12977    True   False     False       False
# 10064    True   False     False       False
# 16162   False   False      True       False
# 4784    False   False     False       False
# ...       ...     ...       ...         ...
# 6597    False   False     False       False
# 9632     True   False     False       False
# 14437   False   False     False        True
# 871     False   False      True       False
# 15350   False   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.loc[:,train_df.columns!='ocean_proximity'].corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude',y='longitude',data=train_df, hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_df['bedroom_ratio']=train_df['total_bedrooms']/train_df['total_rooms']
train_df['household_rooms']=train_df['total_rooms']/train_df['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.loc[:,train_df.columns!='ocean_proximity'].corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train, y_train=train_df.drop(['median_house_value'],axis=1),train_df['median_house_value']
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_df=x_test.join(y_test)

test_df['total_rooms']=np.log(test_df['total_rooms']+1)
test_df['total_bedrooms']=np.log(test_df['total_bedrooms']+1)
test_df['population']=np.log(test_df['population']+1)
test_df['households']=np.log(test_df['households']+1)

test_df=test_df.join(pd.get_dummies(test_df.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_df['bedroom_ratio']=test_df['total_bedrooms']/test_df['total_rooms']
test_df['household_rooms']=test_df['total_rooms']/test_df['households']

# %%
test_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17848    -121.86     37.42                  20     8.523772        6.695799
# 11931    -117.39     33.95                  35     8.103797        6.523562
# 15876    -122.41     37.75                  52     7.560080        6.003887
# 6656     -118.13     34.15                  18     7.418181        6.169611
# 2239     -119.82     36.84                   9     7.758333        6.300786
# ...          ...       ...                 ...          ...             ...
# 13073    -121.33     38.57                  17     7.391415        5.860786
# 414      -122.28     37.89                  52     7.869784        6.161207
# 12015    -117.50     33.93                  19     8.464214        6.728629
# 17151    -122.19     37.43                  39     7.780303        6.042633
# 15519    -117.09     33.15                  13     8.283747        6.763885
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 17848    7.899524    6.687109         6.6227              264800       True
# 11931    7.463363    6.513230         3.7109              109100      False
# 15876    7.302496    6.045005         3.4063              253900      False
# 6656     6.999422    5.968708         2.6038              155600       True
# 2239     6.758095    6.255750         3.3229              119300      False
# ...           ...         ...            ...                 ...        ...
# 13073    6.561031    5.826000         2.3684              150000      False
# 414      6.990257    6.190315         4.1250              270900      False
# 12015    7.973844    6.680855         4.3723              135600      False
# 17151    6.843750    6.008813         6.6136              472800      False
# 15519    7.591862    6.734592         3.4764              137500       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 17848   False   False     False       False       0.785544         1.274657
# 11931    True   False     False       False       0.805001         1.244205
# 15876   False   False      True       False       0.794157         1.250633
# 6656    False   False     False       False       0.831688         1.242845
# 2239     True   False     False       False       0.812131         1.240192
# ...       ...     ...       ...         ...            ...              ...
# 13073    True   False     False       False       0.792918         1.268695
# 414     False   False      True       False       0.782894         1.271306
# 12015    True   False     False       False       0.794950         1.266936
# 17151   False   False     False        True       0.776658         1.294815
# 15519   False   False     False       False       0.816525         1.230030
#
# [4087 rows x 16 columns]

# %%
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6424     -118.00     34.14                  39     7.172425        5.717028
# 12977    -121.32     38.67                  31     7.837160        6.173786
# 10064    -121.03     39.37                  15     7.198931        5.789960
# 16162    -122.50     37.78                  50     7.561642        6.059123
# 4784     -118.32     34.03                  47     6.987490        5.293305
# ...          ...       ...                 ...          ...             ...
# 6597     -118.16     34.18                  44     7.534228        5.966147
# 9632     -121.01     37.25                  16     7.703910        6.129050
# 14437    -117.24     32.80                  18     7.698936        6.495266
# 871      -122.07     37.52                   3     9.547883        7.959276
# 15350    -117.30     33.26                  23     7.425954        5.620401
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6424     6.685861    5.676754         3.2723              166900      False
# 12977    7.242082    6.148468         4.0417              114500      False
# 10064    7.067320    5.726848         2.6341               85000      False
# 16162    6.956545    6.095825         3.5833              348500      False
# 4784     6.122493    5.267858         3.0132              223200       True
# ...           ...         ...            ...                 ...        ...
# 6597     7.204893    5.971262         1.8932              136100       True
# 9632     7.035269    6.052089         2.7316               97500      False
# 14437    6.774224    6.364751         3.8018              112500      False
# 871      8.882669    7.920810         6.0824              273500      False
# 15350    7.113142    5.579730         4.1713              133800       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 6424     True   False     False       False       0.797084         1.263473
# 12977    True   False     False       False       0.787758         1.274652
# 10064    True   False     False       False       0.804281         1.257050
# 16162   False   False      True       False       0.801297         1.240462
# 4784    False   False     False       False       0.757540         1.326439
# ...       ...     ...       ...         ...            ...              ...
# 6597    False   False     False       False       0.791872         1.261748
# 9632     True   False     False       False       0.795577         1.272934
# 14437   False   False     False        True       0.843658         1.209621
# 871     False   False      True       False       0.833617         1.205418
# 15350   False   False     False       False       0.756859         1.330881
#
# [16346 rows x 16 columns]

# %%
x_test, y_test=test_df.drop(['median_house_value'],axis=1),test_df['median_house_value']

# %%
reg.score(x_test,y_test)
# Out:
# 0.6933781817741624

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8147420075579312

# %%
from sklearn.model_selection import GridSearchCV
param_grid={
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}
    
grid_search=GridSearchCV(forest, param_grid, cv=5,
scoring="neg_mean_squared_error",
return_train_score=True)

grid_search.fit(x_train,y_train)

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(x_test,y_test)
# Out:
# 0.814065259595099
